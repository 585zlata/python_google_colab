# %% [markdown]
# <a href="https://colab.research.google.com/github/585zlata/python_google_colab/blob/main/Intro_to_pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/titanic.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=pd.DataFrame.from_dict({'a':[1,2], 'b':[3,4]})

# %%
df2
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df.to_csv('/tmp2.csv')

# %%
df9=pd.read_csv('/tmp2.csv')

# %%
df9
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#фильтрация

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name'].shape
# Out:
# (891,)

# %%
df[['Age','Name']].head(3)
# Out:
#     Age                                               Name
# 0  22.0                            Braund, Mr. Owen Harris
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0                             Heikkinen, Miss. Laina

# %%
df.loc[[5,10,15],['Name','Age']]
# Out:
#                                 Name   Age
# 5                   Moran, Mr. James   NaN
# 10   Sandstrom, Miss. Marguerite Rut   4.0
# 15  Hewlett, Mrs. (Mary D Kingcome)   55.0

# %%
df.iloc[[5,10,15],[0,1]]
# Out:
#     PassengerId  Survived
# 5             6         0
# 10           11         1
# 15           16         1

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.iloc[5:11,:3]
# Out:
#     PassengerId  Survived  Pclass
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3

# %%
#фильстровать по булевой маске ([df['Age']>18])

# %%
df[df['Age']>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age']>18 #булевая маска
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isin([5,23,22])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 58            59         1       2
# 60            61         0       3
# 80            81         0       3
# 88            89         1       1
# 97            98         1       1
# 112          113         0       3
# 135          136         0       2
# 141          142         1       3
# 151          152         1       1
# 212          213         0       3
# 225          226         0       3
# 233          234         1       3
# 243          244         0       3
# 287          288         0       3
# 289          290         1       3
# 320          321         0       3
# 323          324         1       2
# 350          351         0       3
# 356          357         1       1
# 373          374         0       1
# 376          377         1       3
# 393          394         1       1
# 395          396         0       3
# 398          399         0       2
# ...

# %%
df[(df['Age']==5)|(df['Age']==9)]
# Out:
#      PassengerId  Survived  Pclass  \
# 58            59         1       2
# 147          148         0       3
# 165          166         1       3
# 182          183         0       3
# 233          234         1       3
# 448          449         1       3
# 480          481         0       3
# 489          490         1       3
# 541          542         0       3
# 634          635         0       3
# 777          778         1       3
# 852          853         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 58                      West, Miss. Constance Mirium  female  5.0      1
# 147                 Ford, Miss. Robina Maggie "Ruby"  female  9.0      2
# 165  Goldsmith, Master. Frank John William "Frankie"    male  9.0      0
# 182            Asplund, Master. Clarence Gustaf Hugo    male  9.0      4
# 233                   Asplund, Miss. Lillian Gertrud  female  5.0      4
# ...

# %%
df['Age'].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isna().sum()
# Out:
# 177

# %%
df.loc[df['Age'].notna(),'Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 885                 Rice, Mrs. William (Margaret Norton)
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 714, dtype: object

# %%
# сортировка

# %%
df.sort_values('Age').head(10)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 831          832         1       2  Richards, Master. George Sibley    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 827          828         1       2            Mallet, Master. Andre    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 164          165         0       3     Panula, Master. Eino Viljami    male
#
#       Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# ...

# %%
df.sort_values(['Age'],ascending=[False]).head(9)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0       27042  30.0000   A23        S
# 851  male  74.0      0      0      347060   7.7750   NaN        S
# ...

# %%
df.sort_values(['Age', 'Name'], ascending=[False,True]).head(12)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 33            34         0       2                 Wheadon, Mr. Edward H
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 438          439         0       1                     Fortune, Mr. Mark
#
# ...

# %%
#объединение 2х датафреймов

# %%
df2=df.copy(deep=True)

# %%
cdf1=pd.concat([df,df2])

# %%
cdf1.shape
# Out:
# (1782, 12)

# %%
df.shape
# Out:
# (891, 12)

# %%
cdf1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#конкатенация по столбцам

# %%
cdf2=pd.concat([df,df2], axis = 1)

# %%
cdf2.shape
# Out:
# (891, 24)

# %%
#создаем пустой датафрейм с таким же индексом как в изначальном датафрейме

# %%
mdf=pd.DataFrame(index=df.index)

# %%
mdf['PassengerId']=df['PassengerId']

# %%
mdf['evenId']=mdf['PassengerId'].apply(lambda d: d%2==0)

# %%
mdf
# Out:
#      PassengerId  evenId
# 0              1   False
# 1              2    True
# 2              3   False
# 3              4    True
# 4              5   False
# ..           ...     ...
# 886          887   False
# 887          888    True
# 888          889   False
# 889          890    True
# 890          891   False
#
# [891 rows x 2 columns]

# %%
pd.merge(df,mdf,how='inner')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#аналитические функции

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df['Age'].count
# Out:
# <bound method Series.count of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
df['Age'].mean(), df['Age'].median()
# Out:
# (29.69911764705882, 28.0)

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df.groupby(['Sex','Survived'])['Age'].agg(['mean','median'])
# Out:
#                       mean  median
# Sex    Survived
# female 0         25.046875    24.5
#        1         28.847716    28.0
# male   0         31.618056    29.0
#        1         27.276022    28.0

# %%
df['Sex'].value_counts
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-96-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
#визуализация

# %%
df['Age'].plot(kind='hist',bins=130)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde', xlim = [0,80])
# Out:
# <Axes: ylabel='Density'>

# %%
df. groupby('Sex')['Age'].plot(kind= 'kde', xlim =[0,100], legend= True)
# Out:
# Sex
# female    Axes(0.125,0.11;0.775x0.77)
# male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
tmp_df= df.copy(deep=True)

# %%
tmp_df['Pclass']=1

# %%
tmp_df['Pclass'].value_counts()
# Out:
# 1    891
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
tmp_df['isReallyAdult']=tmp_df['Age']>=18

# %%
tmp_df[['Age', 'isReallyAdult']].head(10)
# Out:
#     Age  isReallyAdult
# 0  22.0           True
# 1  38.0           True
# 2  26.0           True
# 3  35.0           True
# 4  35.0           True
# 5   NaN          False
# 6  54.0           True
# 7   2.0          False
# 8  27.0           True
# 9  14.0          False

# %%
tmp_df['isAdultSurvived']=tmp_df['isReallyAdult']

# %%
#функция loc для изменения некоторых значений
#лишнее РАВНО
tmp_df.loc[tmp_df['Survived']==0, 'isAdultSurvived']==False
# Out:
# 0      True
# 4      True
# 5      True
# 6      True
# 7      True
#        ...
# 884    True
# 885    True
# 886    True
# 888    True
# 890    True
# Name: isAdultSurvived, Length: 549, dtype: bool

# %%
tmp_df['isAdultSurvived'] = tmp_df['isReallyAdult']
tmp_df.loc[tmp_df['Survived'] == 0, 'isAdultSurvived'] = False

# %%
tmp_df.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       1
# 877          878         0       1
# 878          879         0       1
# 879          880         1       1
# 880          881         1       1
# 881          882         0       1
# 882          883         0       1
# 883          884         0       1
# 884          885         0       1
# 885          886         0       1
# 886          887         0       1
# 887          888         1       1
# 888          889         0       1
# 889          890         1       1
# 890          891         0       1
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %%
tmp_df.rename(
    columns={'isAdultSurvived':'isAdultSurvived123'}
).head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       1
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  isAdult  isReallyAdult  \
# 0      0  A/5 21171   7.2500   NaN        S     True           True
# 1      0   PC 17599  71.2833   C85        C     True           True
#
#    isAdultSurvived123
# 0               False
# 1                True

# %%
tmp_df.rename(columns=str.lower).head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       1
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked  isadult  isreallyadult  \
# 0      0  A/5 21171   7.2500   NaN        S     True           True
# 1      0   PC 17599  71.2833   C85        C     True           True
#
#    isadultsurvived
# 0            False
# 1             True

# %%
tmp_df['lower_case_name']=tmp_df['Name'].apply(lambda S: S.lower())

# %%
tmp_df['lower_case_name']
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: lower_case_name, Length: 891, dtype: object

# %%
tmp_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'isAdult',
#        'isReallyAdult', 'isAdultSurvived', 'lower_case_name'],
#       dtype='object')

# %%
tmp_df['Name_to_lower_case']=tmp_df['Name'].str.lower()

# %%
tmp_df['Name_to_lower_case']
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name_to_lower_case, Length: 891, dtype: object

# %%
tmp_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'isAdult',
#        'isReallyAdult', 'isAdultSurvived', 'lower_case_name',
#        'Name_to_lower_case'],
#       dtype='object')
